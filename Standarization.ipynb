# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('F:\poralekha\programming\python\dataset\Social_Network_Ads.csv')

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 10    26            80000          0
# 87    28            85000          0
# 8     25            33000          0
# 350   38           113000          1
# 245   51           146000          1

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop('Purchased', axis = 1), df['Purchased'], test_size=.3 , random_state=0)

# %%
x_train.shape, x_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# # Standard scaler

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
## Now i am going to fit the train set , it will learn the parameter from it
scaler.fit(x_train)

## Now I am going to trainsform the train and test datset for x

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
scaler.mean_
# Out:
# array([3.78642857e+01, 6.98071429e+04])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled , columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled , columns = x_test.columns)
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]

# %% [markdown]
# # Effect of scaling

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2 , figsize = (12,5))

ax1.scatter(x_train['Age'],x_train['EstimatedSalary'])
ax1.set_title("Before scaling")

ax2.scatter(x_train_scaled['Age'],x_train_scaled['EstimatedSalary'],color = 'red')
ax2.set_title("After scaling")

plt.show()
